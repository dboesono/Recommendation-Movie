# %% [markdown]
# ## Import Packages

# %%
import sys
import numpy as np

# %% [markdown]
# ## Import Modules

# %%
sys.path.append("../")

# %%
from src.models import BaselinePredictor as BP
from src.models import projectLib as lib

# %% [markdown]
# ## Baseline Predictor

# %%
training = lib.getTrainingData()
validation = lib.getValidationData()
model = BP.model()
model.fit(training, validation)
model.plot()
# Out:
# Linear regression, l = 0.000000
# RMSE for training 2.048609
# RMSE for validation 2.058839
# Linear regression, l = 1.052632
# RMSE for training 0.877742
# RMSE for validation 0.897965
# Linear regression, l = 2.105263
# RMSE for training 0.878941
# RMSE for validation 0.897897
# Linear regression, l = 3.157895
# RMSE for training 0.880005
# RMSE for validation 0.897872
# Linear regression, l = 4.210526
# RMSE for training 0.880961
# RMSE for validation 0.897890
# Linear regression, l = 5.263158
# RMSE for training 0.881840
# RMSE for validation 0.897950
# Linear regression, l = 6.315789
# RMSE for training 0.882661
# RMSE for validation 0.898046
# Linear regression, l = 7.368421
# RMSE for training 0.883438
# RMSE for validation 0.898174
# Linear regression, l = 8.421053
# RMSE for training 0.884182
# RMSE for validation 0.898330
# Linear regression, l = 9.473684
# RMSE for training 0.884900
# RMSE for validation 0.898510
# Linear regression, l = 10.526316
# RMSE for training 0.885597
# RMSE for validation 0.898713
# Linear regression, l = 11.578947
# RMSE for training 0.886277
# RMSE for validation 0.898935
# Linear regression, l = 12.631579
# RMSE for training 0.886944
# RMSE for validation 0.899174
# Linear regression, l = 13.684211
# RMSE for training 0.887599
# RMSE for validation 0.899430
# Linear regression, l = 14.736842
# RMSE for training 0.888245
# RMSE for validation 0.899699
# Linear regression, l = 15.789474
# RMSE for training 0.888882
# RMSE for validation 0.899980
# Linear regression, l = 16.842105
# RMSE for training 0.889511
# RMSE for validation 0.900274
# Linear regression, l = 17.894737
# RMSE for training 0.890134
# RMSE for validation 0.900576
# Linear regression, l = 18.947368
# RMSE for training 0.890751
# RMSE for validation 0.900889
# Linear regression, l = 20.000000
# RMSE for training 0.891363
# RMSE for validation 0.901209
# Best λ value:  3.1578947368421053
# Lowest RMSE for validation:  0.8978715416420078
